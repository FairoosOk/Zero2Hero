# %% [markdown]
# <h1 align="center", style="color:purple">Matplotlib Tutorial: Bar Charts</h1>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <h3>Simple Bar Chart showing revenues of major Tech Companies</h3>

# %%
company=['GOOGL','AMZN','MSFT','FB']
revenue=[90,136,89,27]

# %%
xpos = np.arange(len(company))
xpos
# Out:
# array([0, 1, 2, 3])

# %%
plt.bar(xpos,revenue, label="Revenue")

plt.xticks(xpos,company)
plt.ylabel("Revenue(Bln USD)")
plt.title('Tech Company Stocks')
plt.legend()

# %% [markdown]
# <h3>Multiple Bars showing Revenue and Profit of major US tech companies</h3>

# %%
profit=[40,2,34,12]

# %%
plt.bar(xpos-0.2,revenue,width=0.4, label="Revenue")
plt.bar(xpos+0.2,profit,width=0.4,label="Profit")

plt.xticks(xpos,company)
plt.ylabel("Revenue(Bln USD)")
plt.title('Tech Company Stocks')
plt.legend()

# %% [markdown]
# <h3>Horizontal bar chart using barh function<h3>

# %%
plt.barh(xpos,revenue, label="Revenue")

plt.yticks(xpos,company)
plt.xlabel("Revenue(Bln USD)")
plt.title('Tech Company Stocks')
plt.legend()

# %% [markdown]
# REFER BAR CHART: https://matplotlib.org/api/_as_gen/matplotlib.pyplot.bar.html#matplotlib.pyplot.bar
#
# BAR HORIZONDAL: https://matplotlib.org/api/_as_gen/matplotlib.pyplot.barh.html#matplotlib.pyplot.barh
